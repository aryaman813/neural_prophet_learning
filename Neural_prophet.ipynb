# %% [markdown]
# Neural Prophet

# %%
# !pip uninstall -y torch notebook notebook_shim tensorflow tensorflow-datasets prophet torchaudio torchdata torchtext torchvision

# !pip install git+https://github.com/ourownstory/neural_prophet.git
# Out:
# Found existing installation: torch 2.3.1
# Uninstalling torch-2.3.1:
#   Successfully uninstalled torch-2.3.1
# WARNING: Skipping notebook as it is not installed.
# WARNING: Skipping notebook_shim as it is not installed.
# WARNING: Skipping tensorflow as it is not installed.
# WARNING: Skipping tensorflow-datasets as it is not installed.
# WARNING: Skipping prophet as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping torchdata as it is not installed.
# WARNING: Skipping torchtext as it is not installed.
# WARNING: Skipping torchvision as it is not installed.
# Collecting git+https://github.com/ourownstory/neural_prophet.git
#   Cloning https://github.com/ourownstory/neural_prophet.git to /tmp/pip-req-build-q45oyswv
#   Running command git clone --filter=blob:none --quiet https://github.com/ourownstory/neural_prophet.git /tmp/pip-req-build-q45oyswv
#   Resolved https://github.com/ourownstory/neural_prophet.git to commit 5e6b2314547334bbd5dbfc9cc5e019efcb3d67c5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: captum>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (0.8.0)
# Requirement already satisfied: holidays<1.0,>=0.41 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (0.86)
# Requirement already satisfied: kaleido==0.2.1 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (0.2.1)
# Requirement already satisfied: lightning-fabric<2.4.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (2.3.3)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (3.10.0)
# Requirement already satisfied: numpy<2.0.0,>=1.25.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (2.2.2)
# Requirement already satisfied: plotly>=5.13.1 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (5.24.1)
# Requirement already satisfied: pytorch-lightning<2.4.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (2.3.3)
# Requirement already satisfied: tensorboard>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (2.19.0)
# Collecting torch<2.4.0,>=2.0.0 (from neuralprophet==1.0.0rc10)
#   Using cached torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Requirement already satisfied: torchmetrics>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (1.8.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.12/dist-packages (from neuralprophet==1.0.0rc10) (4.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from captum>=0.6.0->neuralprophet==1.0.0rc10) (25.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from captum>=0.6.0->neuralprophet==1.0.0rc10) (4.67.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from holidays<1.0,>=0.41->neuralprophet==1.0.0rc10) (2.9.0.post0)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (2025.3.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (0.15.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.5.3->neuralprophet==1.0.0rc10) (3.2.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->neuralprophet==1.0.0rc10) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->neuralprophet==1.0.0rc10) (2025.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.13.1->neuralprophet==1.0.0rc10) (9.1.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.12/dist-packages (from pytorch-lightning<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (6.0.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (1.76.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (3.10)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (3.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (3.20.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.12/dist-packages (from torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (12.9.86)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (3.13.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.11.2->neuralprophet==1.0.0rc10) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->lightning-fabric<2.4.0,>=2.0.0->neuralprophet==1.0.0rc10) (3.11)
# Using cached torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl (779.1 MB)
# Installing collected packages: torch
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastai 2.8.6 requires torchvision>=0.11, which is not installed.
# timm 1.0.22 requires torchvision, which is not installed.
# Successfully installed torch-2.3.1

# %%
import pandas as pd
import yfinance as yf

from neuralprophet import NeuralProphet, set_log_level
# Out:
# ERROR:NP.plotly:Importing plotly failed. Interactive plots will not work.
# ERROR:NP.plotly:Importing plotly failed. Interactive plots will not work.

# %%
df = yf.download("AAPL", start="2016-01-01", end="2024-01-01", auto_adjust=False, multi_level_index=False)

df = df["Close"]

df = df.reset_index()

df = df.rename(columns = {"Date":"ds", "Close":"y"})

plt = df.plot(x="ds", y="y", figsize=(12, 6))
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
set_log_level("ERROR")

m = NeuralProphet()

m.set_plotting_backend("plotly-static")

metrics = m.fit(df)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
# Training: |          | 0/? [00:00<?, ?it/s]
# WARNING:pytorch_lightning.loggers.tensorboard:Missing logger folder: /content/lightning_logs
# Finding best initial lr:   0%|          | 0/124 [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 32. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 32. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 28. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/data.py:78: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 28. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
# Training: |          | 0/? [00:00<?, ?it/s]

# %%
df_future = m.make_future_dataframe(df, n_historic_predictions=True, periods=365)

forecast = m.predict(df_future)

m.plot(forecast)
# Out:
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/data/split.py:269: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/data/split.py:269: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, future_df])
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/df_utils.py:1120: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   converted_ds = pd.to_datetime(ds_col, utc=True).view(dtype=np.int64)
# Predicting: |          | 0/? [00:00<?, ?it/s]
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ds = fcst["ds"].dt.to_pydatetime()
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_forecast_plotly.py:100: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   ds = fcst["ds"].dt.to_pydatetime()

# %%
m.plot_parameters(components=["trend", "seasonality"])
# Out:
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:237: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:271: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:475: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:508: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
#
# WARNING - (py.warnings._showwarnmsg) - /usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:564: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#
#
# WARNING:py.warnings:/usr/local/lib/python3.12/dist-packages/neuralprophet/plot_model_parameters_plotly.py:564: FutureWarning:
#
# 'H' is deprecated and will be removed in a future version, please use 'h' instead.
